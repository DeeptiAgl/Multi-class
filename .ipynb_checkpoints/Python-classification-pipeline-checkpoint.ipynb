# %%
import numpy as np
import pandas as pd
import seaborn as sns
import itertools
import matplotlib.pyplot as plt

from sklearn import model_selection
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn import metrics

# Classifiers
from sklearn.svm import SVR
# from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
# from mlxtend.Regressor import StackingCVRegressor #
from mlxtend.classifier import StackingCVClassifier
import xgboost as xgb

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# Used to ignore warnings generated from StackingCVClassifier
import warnings
warnings.simplefilter('ignore')

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, classification_report 
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#   IDENTIF RIVER  LOCATION ERECTED   PURPOSE  LENGTH  LANES CLEAR-G   T-OR-D  \
# 0      E1     M       3.0  CRAFTS   HIGHWAY     NaN    2.0       N  THROUGH
# 1      E2     A      25.0  CRAFTS   HIGHWAY  MEDIUM    2.0       N  THROUGH
# 2      E3     A      39.0  CRAFTS  AQUEDUCT     NaN    1.0       N  THROUGH
# 3      E5     A      29.0  CRAFTS   HIGHWAY  MEDIUM    2.0       N  THROUGH
# 4      E6     M      23.0  CRAFTS   HIGHWAY     NaN    2.0       N  THROUGH
#
#   MATERIAL   SPAN REL-L  TYPE
# 0     WOOD  SHORT     S  WOOD
# 1     WOOD  SHORT     S  WOOD
# 2     WOOD    NaN     S  WOOD
# 3     WOOD  SHORT     S  WOOD
# 4     WOOD    NaN     S  WOOD

# %%
# Drop Colums a & b from dfObj in place
df.drop([106 , 107], inplace=True)

# %%
df['IDENTIF']=df['IDENTIF'].astype('category')
# df['IDENTIF']=df['IDENTIF'].astype('category')
df = df[df.TYPE!= 'NIL']

# %%
X = df.drop('TYPE', axis=1)
y = df[['TYPE']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42,stratify=y)
X_train.head()
# Out:
#    IDENTIF RIVER  LOCATION   ERECTED   PURPOSE  LENGTH  LANES CLEAR-G  \
# 27     E29     A      26.0  EMERGING   HIGHWAY  MEDIUM    2.0       G
# 16     E18     A      28.0    CRAFTS        RR  MEDIUM    2.0       N
# 49     E94     M      13.0    MATURE        RR     NaN    2.0       G
# 6       E8     A      28.0    CRAFTS  AQUEDUCT  MEDIUM    1.0       N
# 87    E108     A      39.5    MODERN   HIGHWAY  MEDIUM    4.0       G
#
#      T-OR-D MATERIAL    SPAN REL-L
# 27  THROUGH    STEEL  MEDIUM   NaN
# 16  THROUGH     IRON   SHORT     S
# 49  THROUGH    STEEL    LONG     F
# 6   THROUGH     IRON   SHORT     S
# 87     DECK    STEEL  MEDIUM   S-F

# %%
df.TYPE.value_counts().plot(kind='bar', title='Count (target)');
df.TYPE.value_counts()
# df_test_over.y.value_counts().plot(kind='bar', title='Count (target)');
# df.drop
#
# Out:
# SIMPLE-T    44
# WOOD        16
# ARCH        13
# CANTILEV    11
# SUSPEN      11
# CONT-T      10
# Name: TYPE, dtype: int64

# %%
df.TYPE.value_counts()
# Out:
# SIMPLE-T    44
# WOOD        16
# ARCH        13
# CANTILEV    11
# SUSPEN      11
# CONT-T      10
# Name: TYPE, dtype: int64

# %%
df.shape
# Out:
# (105, 13)

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# Requirement already satisfied: scikit-learn>=0.23 in c:\users\deepti\anaconda3\envs\assignment\lib\site-packages (from imbalanced-learn->imblearn) (0.23.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\deepti\anaconda3\envs\assignment\lib\site-packages (from imbalanced-learn->imblearn) (1.18.5)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\deepti\anaconda3\envs\assignment\lib\site-packages (from imbalanced-learn->imblearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\deepti\anaconda3\envs\assignment\lib\site-packages (from imbalanced-learn->imblearn) (0.15.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\deepti\anaconda3\envs\assignment\lib\site-packages (from scikit-learn>=0.23->imbalanced-learn->imblearn) (2.1.0)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.7.0 imblearn-0.0

# %%
import seaborn as sns
sns.pairplot(df, hue='TYPE', size=3)

# %%
df.dtypes
# Out:
# IDENTIF     category
# RIVER         object
# LOCATION     float64
# ERECTED       object
# PURPOSE       object
# LENGTH        object
# LANES        float64
# CLEAR-G       object
# T-OR-D        object
# MATERIAL      object
# SPAN          object
# REL-L         object
# TYPE           int32
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

df['TYPE'] = LabelEncoder().fit_transform(df['TYPE'])

# %%
df['TYPE'].value_counts()
# Out:
# 3    44
# 5    16
# 0    13
# 4    11
# 1    11
# 2    10
# Name: TYPE, dtype: int64

# %%
n_estimators = [50,100,300,500]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [5,15,20]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [1,2,3, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 3, 5]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
pipe_stack.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocess',
#    ColumnTransformer(transformers=[('num',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('scaler', StandardScaler())]),
#                                     Index(['LOCATION', 'LANES'], dtype='object')),
#                                    ('cat',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(fill_value='missing',
#                                                                    strategy='constant')),
#                                                     ('onehot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#           'MATERIAL', 'SPAN', 'REL-L'],
#          dtype='object'))])),
#   ('model', RandomForestClassifier(n_jobs=-1, random_state=1000))],
#  'verbose': False,
#  'preprocess': ColumnTransformer(transformers=[('num',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(strategy='median')),
#                                                   ('scaler', StandardScaler())]),
#                                   Index(['LOCATION', 'LANES'], dtype='object')),
#                                  ('cat',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(fill_value='missing',
#                                                                  strategy='constant')),
#                                                   ('onehot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#         'MATERIAL', 'SPAN', 'REL-L'],
#        dtype='object'))]),
#  'model': RandomForestClassifier(n_jobs=-1, random_state=1000),
#  'preprocess__n_jobs': None,
#  'preprocess__remainder': 'drop',
#  'preprocess__sparse_threshold': 0.3,
#  'preprocess__transformer_weights': None,
#  'preprocess__transformers': [('num',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                    ('scaler', StandardScaler())]),
#    Index(['LOCATION', 'LANES'], dtype='object')),
#   ('cat',
#    Pipeline(steps=[('imputer',
#                     SimpleImputer(fill_value='missing', strategy='constant')),
#                    ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#    Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#           'MATERIAL', 'SPAN', 'REL-L'],
#          dtype='object'))],
#  'preprocess__verbose': False,
#  'preprocess__num': Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                  ('scaler', StandardScaler())]),
#  'preprocess__cat': Pipeline(steps=[('imputer',
#                   SimpleImputer(fill_value='missing', strategy='constant')),
#                  ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#  'preprocess__num__memory': None,
#  'preprocess__num__steps': [('imputer', SimpleImputer(strategy='median')),
#   ('scaler', StandardScaler())],
#  'preprocess__num__verbose': False,
#  'preprocess__num__imputer': SimpleImputer(strategy='median'),
#  'preprocess__num__scaler': StandardScaler(),
#  'preprocess__num__imputer__add_indicator': False,
#  'preprocess__num__imputer__copy': True,
#  'preprocess__num__imputer__fill_value': None,
#  'preprocess__num__imputer__missing_values': nan,
#  'preprocess__num__imputer__strategy': 'median',
#  'preprocess__num__imputer__verbose': 0,
#  'preprocess__num__scaler__copy': True,
#  'preprocess__num__scaler__with_mean': True,
#  'preprocess__num__scaler__with_std': True,
#  'preprocess__cat__memory': None,
#  'preprocess__cat__steps': [('imputer',
#    SimpleImputer(fill_value='missing', strategy='constant')),
#   ('onehot', OneHotEncoder(handle_unknown='ignore'))],
#  'preprocess__cat__verbose': False,
#  'preprocess__cat__imputer': SimpleImputer(fill_value='missing', strategy='constant'),
#  'preprocess__cat__onehot': OneHotEncoder(handle_unknown='ignore'),
#  'preprocess__cat__imputer__add_indicator': False,
#  'preprocess__cat__imputer__copy': True,
#  'preprocess__cat__imputer__fill_value': 'missing',
#  'preprocess__cat__imputer__missing_values': nan,
#  'preprocess__cat__imputer__strategy': 'constant',
#  'preprocess__cat__imputer__verbose': 0,
#  'preprocess__cat__onehot__categories': 'auto',
#  'preprocess__cat__onehot__drop': None,
#  'preprocess__cat__onehot__dtype': numpy.float64,
#  'preprocess__cat__onehot__handle_unknown': 'ignore',
#  'preprocess__cat__onehot__sparse': True,
#  'model__bootstrap': True,
#  'model__ccp_alpha': 0.0,
#  'model__class_weight': None,
#  'model__criterion': 'gini',
#  'model__max_depth': None,
#  'model__max_features': 'auto',
#  'model__max_leaf_nodes': None,
#  'model__max_samples': None,
#  'model__min_impurity_decrease': 0.0,
#  'model__min_impurity_split': None,
#  'model__min_samples_leaf': 1,
#  'model__min_samples_split': 2,
#  'model__min_weight_fraction_leaf': 0.0,
#  'model__n_estimators': 100,
#  'model__n_jobs': -1,
#  'model__oob_score': False,
#  'model__random_state': 1000,
#  'model__verbose': 0,
#  'model__warm_start': False}

# %%
# num_indices1 = list(X.iloc[:,np.r_[0:94,95,97,100:120,121:123]].columns.values)
# cat_indices1 = list(X.iloc[:,np.r_[94,96,98,99,120]].columns.values)
from sklearn.pipeline import FeatureUnion, Pipeline

num_features = X_train.select_dtypes(include=['int64', 'float64']).columns
cat_features = X_train.select_dtypes(include=['object']).columns

num_cols_ind = []
for key in num_features:
    ind = X_train.columns.get_loc(key)
    num_cols_ind.append(ind)
    
cat_cols_ind = []
for key in cat_features:
    ind = X_train.columns.get_loc(key)
    cat_cols_ind.append(ind)


# print(len(num_indices1))
# print(len(cat_indices1))

# cat_indices = [94, 96, 98, 99, 120]

from imblearn.pipeline import make_pipeline

pipeline=Pipeline(steps= [
    # Categorical features
    ('feature_processing', FeatureUnion(transformer_list = [ ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
            ('categorical', cat_features),

            #numeric
            ('numeric', Pipeline(steps = [
                ('imputer', SimpleImputer(strategy='median')),
#                 ('select', num_features),
                ('scale', StandardScaler())
                        ]))
        ])),
    ('randomforestclassifier', model)
    ]
)
pipeline_with_resampling = make_pipeline(SMOTENC(categorical_features=cat_indices), pipeline)

params = {
               'pipeline__randomforestclassifier__n_estimators': n_estimators,  #randomforestregressor__bootstrap
               'pipeline__randomforestclassifier__max_features': max_features,
               'pipeline__randomforestclassifier__max_depth': max_depth,
               'pipeline__randomforestclassifier__min_samples_split': min_samples_split,
               'pipeline__randomforestclassifier__min_samples_leaf': min_samples_leaf,
               'pipeline__randomforestclassifier__bootstrap': bootstrap,
#               "xgbclassifier__n_estimators": [10, 50, 100, 500],
#                 "xgbclassifier__learning_rate": [0.1, 0.5, 1],
         }

grid = GridSearchCV(
    verbose=5,
    estimator=pipeline_with_resampling, 
    param_grid=params, 
    cv=3,
    refit=True
)

 

grid.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-d51489e6a6a1> in <module>
#      33                 ('imputer', SimpleImputer(strategy='median')),
#      34                 ('select', num_features),
# ---> 35                 ('scale', StandardScaler())
#      36                         ]))
#      37         ])),
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\pipeline.py in __init__(self, steps, memory, verbose)
#     112         self.memory = memory
#     113         self.verbose = verbose
# --> 114         self._validate_steps()
#     115
#     116     def get_params(self, deep=True):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\pipeline.py in _validate_steps(self)
#     153
#     154         for t in transformers:
# --> 155             if t is None or t == 'passthrough':
#     156                 continue
#     157             if (not (hasattr(t, "fit") or hasattr(t, "fit_transform")) or not
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
pipe_stack.get_params()
# Out:
# {'memory': None,
#  'steps': [('smotenc',
#    SMOTENC(categorical_features=[0, 1, 3, 4, 5, 7, 8, 9, 10, 11], random_state=42)),
#   ('pipeline',
#    Pipeline(steps=[('preprocess',
#                     ColumnTransformer(transformers=[('num',
#                                                      Pipeline(steps=[('imputer',
#                                                                       SimpleImputer(strategy='median')),
#                                                                      ('scaler',
#                                                                       StandardScaler())]),
#                                                      Index(['LOCATION', 'LANES'], dtype='object')),
#                                                     ('cat',
#                                                      Pipeline(steps=[('imputer',
#                                                                       SimpleImputer(fill_value='missing',
#                                                                                     strategy='constant')),
#                                                                      ('onehot',
#                                                                       OneHotEncoder(handle_unknown='ignore'))]),
#                                                      Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#           'MATERIAL', 'SPAN', 'REL-L'],
#          dtype='object'))])),
#                    ('randomforestclassifier',
#                     RandomForestClassifier(n_jobs=-1, random_state=1000))]))],
#  'verbose': False,
#  'smotenc': SMOTENC(categorical_features=[0, 1, 3, 4, 5, 7, 8, 9, 10, 11], random_state=42),
#  'pipeline': Pipeline(steps=[('preprocess',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(strategy='median')),
#                                                                    ('scaler',
#                                                                     StandardScaler())]),
#                                                    Index(['LOCATION', 'LANES'], dtype='object')),
#                                                   ('cat',
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(fill_value='missing',
#                                                                                   strategy='constant')),
#                                                                    ('onehot',
#                                                                     OneHotEncoder(handle_unknown='ignore'))]),
#                                                    Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#         'MATERIAL', 'SPAN', 'REL-L'],
#        dtype='object'))])),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_jobs=-1, random_state=1000))]),
#  'smotenc__categorical_features': [0, 1, 3, 4, 5, 7, 8, 9, 10, 11],
#  'smotenc__k_neighbors': 5,
#  'smotenc__n_jobs': None,
#  'smotenc__random_state': 42,
#  'smotenc__sampling_strategy': 'auto',
#  'pipeline__memory': None,
#  'pipeline__steps': [('preprocess',
#    ColumnTransformer(transformers=[('num',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(strategy='median')),
#                                                     ('scaler', StandardScaler())]),
#                                     Index(['LOCATION', 'LANES'], dtype='object')),
#                                    ('cat',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(fill_value='missing',
#                                                                    strategy='constant')),
#                                                     ('onehot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#           'MATERIAL', 'SPAN', 'REL-L'],
#          dtype='object'))])),
#   ('randomforestclassifier',
#    RandomForestClassifier(n_jobs=-1, random_state=1000))],
#  'pipeline__verbose': False,
#  'pipeline__preprocess': ColumnTransformer(transformers=[('num',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(strategy='median')),
#                                                   ('scaler', StandardScaler())]),
#                                   Index(['LOCATION', 'LANES'], dtype='object')),
#                                  ('cat',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(fill_value='missing',
#                                                                  strategy='constant')),
#                                                   ('onehot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#         'MATERIAL', 'SPAN', 'REL-L'],
#        dtype='object'))]),
#  'pipeline__randomforestclassifier': RandomForestClassifier(n_jobs=-1, random_state=1000),
#  'pipeline__preprocess__n_jobs': None,
#  'pipeline__preprocess__remainder': 'drop',
#  'pipeline__preprocess__sparse_threshold': 0.3,
#  'pipeline__preprocess__transformer_weights': None,
#  'pipeline__preprocess__transformers': [('num',
#    Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                    ('scaler', StandardScaler())]),
#    Index(['LOCATION', 'LANES'], dtype='object')),
#   ('cat',
#    Pipeline(steps=[('imputer',
#                     SimpleImputer(fill_value='missing', strategy='constant')),
#                    ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#    Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#           'MATERIAL', 'SPAN', 'REL-L'],
#          dtype='object'))],
#  'pipeline__preprocess__verbose': False,
#  'pipeline__preprocess__num': Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                  ('scaler', StandardScaler())]),
#  'pipeline__preprocess__cat': Pipeline(steps=[('imputer',
#                   SimpleImputer(fill_value='missing', strategy='constant')),
#                  ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#  'pipeline__preprocess__num__memory': None,
#  'pipeline__preprocess__num__steps': [('imputer',
#    SimpleImputer(strategy='median')),
#   ('scaler', StandardScaler())],
#  'pipeline__preprocess__num__verbose': False,
#  'pipeline__preprocess__num__imputer': SimpleImputer(strategy='median'),
#  'pipeline__preprocess__num__scaler': StandardScaler(),
#  'pipeline__preprocess__num__imputer__add_indicator': False,
#  'pipeline__preprocess__num__imputer__copy': True,
#  'pipeline__preprocess__num__imputer__fill_value': None,
#  'pipeline__preprocess__num__imputer__missing_values': nan,
#  'pipeline__preprocess__num__imputer__strategy': 'median',
#  'pipeline__preprocess__num__imputer__verbose': 0,
#  'pipeline__preprocess__num__scaler__copy': True,
#  'pipeline__preprocess__num__scaler__with_mean': True,
#  'pipeline__preprocess__num__scaler__with_std': True,
#  'pipeline__preprocess__cat__memory': None,
#  'pipeline__preprocess__cat__steps': [('imputer',
#    SimpleImputer(fill_value='missing', strategy='constant')),
#   ('onehot', OneHotEncoder(handle_unknown='ignore'))],
#  'pipeline__preprocess__cat__verbose': False,
#  'pipeline__preprocess__cat__imputer': SimpleImputer(fill_value='missing', strategy='constant'),
#  'pipeline__preprocess__cat__onehot': OneHotEncoder(handle_unknown='ignore'),
#  'pipeline__preprocess__cat__imputer__add_indicator': False,
#  'pipeline__preprocess__cat__imputer__copy': True,
#  'pipeline__preprocess__cat__imputer__fill_value': 'missing',
#  'pipeline__preprocess__cat__imputer__missing_values': nan,
#  'pipeline__preprocess__cat__imputer__strategy': 'constant',
#  'pipeline__preprocess__cat__imputer__verbose': 0,
#  'pipeline__preprocess__cat__onehot__categories': 'auto',
#  'pipeline__preprocess__cat__onehot__drop': None,
#  'pipeline__preprocess__cat__onehot__dtype': numpy.float64,
#  'pipeline__preprocess__cat__onehot__handle_unknown': 'ignore',
#  'pipeline__preprocess__cat__onehot__sparse': True,
#  'pipeline__randomforestclassifier__bootstrap': True,
#  'pipeline__randomforestclassifier__ccp_alpha': 0.0,
#  'pipeline__randomforestclassifier__class_weight': None,
#  'pipeline__randomforestclassifier__criterion': 'gini',
#  'pipeline__randomforestclassifier__max_depth': None,
#  'pipeline__randomforestclassifier__max_features': 'auto',
#  'pipeline__randomforestclassifier__max_leaf_nodes': None,
#  'pipeline__randomforestclassifier__max_samples': None,
#  'pipeline__randomforestclassifier__min_impurity_decrease': 0.0,
#  'pipeline__randomforestclassifier__min_impurity_split': None,
#  'pipeline__randomforestclassifier__min_samples_leaf': 1,
#  'pipeline__randomforestclassifier__min_samples_split': 2,
#  'pipeline__randomforestclassifier__min_weight_fraction_leaf': 0.0,
#  'pipeline__randomforestclassifier__n_estimators': 100,
#  'pipeline__randomforestclassifier__n_jobs': -1,
#  'pipeline__randomforestclassifier__oob_score': False,
#  'pipeline__randomforestclassifier__random_state': 1000,
#  'pipeline__randomforestclassifier__verbose': 0,
#  'pipeline__randomforestclassifier__warm_start': False}

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import SMOTENC

# from sklearn.preprocessing import Imputer
from sklearn.impute import SimpleImputer 
from imblearn.pipeline import make_pipeline
# imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

cat_cols_ind = []
for key in cat_features:
    ind = X_train.columns.get_loc(key)
    cat_cols_ind.append(ind)

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

smote_nc = SMOTENC(categorical_features=cat_cols_ind, random_state=42)


# oversample = SMOTE()
# X, y = SMOTE().fit_resample(X, y)

num_features = X_train.select_dtypes(include=['int64', 'float64']).columns
cat_features = X_train.select_dtypes(include=['object']).columns

model = RandomForestClassifier(n_jobs = -1, random_state = 1000)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_features),
        ('cat', categorical_transformer, cat_features)])

# preprocess = make_column_transformer((numeric_transformer num_features),
#                                     categorical_transformer,cat_features))

# smote_nc = 
# SMOTENC(categorical_features=cat_features, random_state=0)
# steps = [('preprocess',preprocessor),('randomforestclassifier',model)]

steps = [('preprocess',preprocessor),
         ('randomforestclassifier',model)]

pipe = Pipeline(steps = steps) 
pipe_stack = make_pipeline(SMOTENC(categorical_features=cat_cols_ind), pipe)



params = {
               'pipeline__randomforestclassifier__n_estimators': n_estimators,  #randomforestregressor__bootstrap
               'pipeline__randomforestclassifier__max_features': max_features,
               'pipeline__randomforestclassifier__max_depth': max_depth,
               'pipeline__randomforestclassifier__min_samples_split': min_samples_split,
               'pipeline__randomforestclassifier__min_samples_leaf': min_samples_leaf,
               'pipeline__randomforestclassifier__bootstrap': bootstrap,
#               "xgbclassifier__n_estimators": [10, 50, 100, 500],
#                 "xgbclassifier__learning_rate": [0.1, 0.5, 1],
         }

grid = GridSearchCV(
    verbose=5,
    estimator=pipe_stack, 
    param_grid=params, 
    cv=3,
    refit=True
)

 

grid.fit(X_train, y_train)                                    
                                    
# Pipeline([('preprocessor', preprocess),('stackingcvregressor',stacking_model)])

# resampled_training_inputs, resampled_training_outputs_labels = sm.fit_resample(X_train, y_train)
# resampled_training_outputs = [one_hot(c,z) for c in resampled_training_outputs_labels]

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import SMOTENC

# from sklearn.preprocessing import Imputer
from sklearn.impute import SimpleImputer 

num_features = X_train.select_dtypes(include=['int64', 'float64']).columns
cat_features = X_train.select_dtypes(include=['object','category']).columns

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values=np.nan, strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values=np.nan,strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_features),
        ('cat', categorical_transformer, cat_features)])

# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
model = RandomForestClassifier(n_jobs = -1, random_state = 1000, class_weight = "balanced_subsample")

pipe_stack = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', model)])

pipe_stack.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['LOCATION', 'LANES'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['IDENTIF', 'RIVER', 'ERECTED', 'PURPOSE', 'LENGTH', 'CLEAR-G', 'T-OR-D',
#        'MATERIAL', 'SPAN', 'REL-L'],
#       dtype='object'))])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced_subsample',
#                                         n_jobs=-1, random_state=1000))])

# %%
# Split Train and Test
# X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33, random_state=42)
# Set variables

from sklearn.experimental import enable_iterative_imputer, enable_hist_gradient_boosting
from sklearn.impute import SimpleImputer, IterativeImputer, KNNImputer


ohe = OneHotEncoder(handle_unknown='ignore', sparse=True)
# imputer_numerical = SimpleImputer(add_indicator=True, verbose=1, strategy='most_frequent')
imputer_numerical =  IterativeImputer(random_state=0)
imputer_categorical = SimpleImputer(strategy='most_frequent',verbose = 1,add_indicator=True)
# imputer_categorical = KNNImputer(n_neighbors=2)
scaler = StandardScaler()
# clf = DecisionTreeClassifier()
# Make Transformer
model = RandomForestClassifier(n_jobs = -1, random_state = 1000, class_weight = "balanced_subsample")

preprocessing = make_column_transformer(
(make_pipeline(imputer_numerical,scaler),num_features)
,(make_pipeline(imputer_categorical,ohe),cat_features)
,remainder='passthrough')
# Make pipeline
pipe = make_pipeline(preprocessing, model)
# Fit model
pipe.fit(X_train, y_train.values.ravel())
print("Best score : %f" % pipe.score(X_test, y_test.values.ravel()))
# Out:
# Best score : 0.685714

# %%
print(pipe_stack.predict(X_test))
print("model score: %.3f" % pipe_stack.score(X_test, y_test))
# Out:
# ['SIMPLE-T' 'CANTILEV' 'SIMPLE-T' 'SIMPLE-T' 'WOOD' 'SIMPLE-T' 'SIMPLE-T'
#  'SIMPLE-T' 'SIMPLE-T' 'CONT-T' 'SIMPLE-T' 'CANTILEV' 'CONT-T' 'SIMPLE-T'
#  'SUSPEN' 'SIMPLE-T' 'WOOD' 'WOOD' 'ARCH' 'CONT-T' 'SIMPLE-T' 'WOOD'
#  'SIMPLE-T' 'SIMPLE-T' 'ARCH' 'SIMPLE-T' 'SIMPLE-T' 'SIMPLE-T' 'SIMPLE-T'
#  'SIMPLE-T' 'WOOD' 'SIMPLE-T' 'WOOD' 'SIMPLE-T' 'SIMPLE-T']
# model score: 0.686

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import SMOTENC

# from sklearn.preprocessing import Imputer
from sklearn.impute import SimpleImputer 
# from imblearn.pipeline import make_pipeline
# from sklearn.experimental import enable_iterative_imputer, enable_hist_gradient_boosting
# from sklearn.impute import SimpleImputer, IterativeImputer, KNNImputer# imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

num_features = X_train.select_dtypes(include=['int64', 'float64']).columns
cat_features = X_train.select_dtypes(include=['object','category']).columns

cat_cols_ind = []
for key in cat_features:
    ind = X_train.columns.get_loc(key)
    cat_cols_ind.append(ind)

# smote_nc = SMOTENC(categorical_features=cat_cols_ind, random_state=42,k_neighbors=2)


# oversample = SMOTE()
# X, y = SMOTE().fit_resample(X, y)

model = RandomForestClassifier(n_jobs = -1, random_state = 1000, class_weight = "balanced_subsample")

# preprocessor1 = make_column_transformer(
#         (SimpleImputer(strategy='median', axis = 0), num_features),
#         (StandardScaler(), num_features),
#     (SimpleImputer(strategy='constant', fill_value='missing', axis = 0), cat_features),
#     (OneHotEncoder(handle_unknown='ignore'), cat_features),
#     remainder = 'passthrough')

preprocess = make_column_transformer( (SimpleImputer(strategy='median'), num_features), 
                                    (SimpleImputer(strategy='constant', fill_value='missing'), cat_features),
                                    (StandardScaler(), num_features),
                                    (OneHotEncoder(handle_unknown='ignore'),cat_features))

# stacking_model = StackingCVRegressor(regressors=(rf,lr), 
#                             meta_regressor=lr,
#                             random_state=42)

pipe_stack = Pipeline([('preprocessor', preprocess),('rf',model)])
    
# pipe_stack = make_pipeline(preprocessor1,model)

pipe_stack.fit(X_train, y_train)

# params = {
#                'pipeline__randomforestclassifier__n_estimators': n_estimators,  #randomforestregressor__bootstrap
#                'pipeline__randomforestclassifier__max_features': max_features,
#                'pipeline__randomforestclassifier__max_depth': max_depth,
#                'pipeline__randomforestclassifier__min_samples_split': min_samples_split,
#                'pipeline__randomforestclassifier__min_samples_leaf': min_samples_leaf,
#                'pipeline__randomforestclassifier__bootstrap': bootstrap,}
# #               "xgbclassifier__n_estimators": [10, 50, 100, 500],
# #                 "xgbclassifier__learning_rate": [0.1, 0.5, 1],
# #          }

# grid = GridSearchCV( verbose=5, estimator=pipe_stack, param_grid=params, cv=3, refit=True )

 

# grid.fit(X_train, y_train)                                    
                                    
# Pipeline([('preprocessor', preprocess),('stackingcvregressor',stacking_model)])

# resampled_training_inputs, resampled_training_outputs_labels = sm.fit_resample(X_train, y_train)
# resampled_training_outputs = [one_hot(c,z) for c in resampled_training_outputs_labels]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-675daca9a278> in <module>
#      44 # pipe_stack = make_pipeline(preprocessor1,model)
#      45
# ---> 46 pipe_stack.fit(X_train, y_train)
#      47
#      48 # params = {
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     328         """
#     329         fit_params_steps = self._check_fit_params(**fit_params)
# --> 330         Xt = self._fit(X, y, **fit_params_steps)
#     331         with _print_elapsed_time('Pipeline',
#     332                                  self._log_message(len(self.steps) - 1)):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     294                 message_clsname='Pipeline',
#     295                 message=self._log_message(step_idx),
# --> 296                 **fit_params_steps[name])
#     297             # Replace the transformer of the step with the fitted
#     298             # transformer. This is necessary when loading the transformer
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\compose\_column_transformer.py in fit_transform(self, X, y)
#     529         self._validate_remainder(X)
#     530
# --> 531         result = self._fit_transform(X, y, _fit_transform_one)
#     532
#     533         if not result:
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\compose\_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     465                     message=self._log_message(name, idx, len(transformers)))
#     466                 for idx, (name, trans, column, weight) in enumerate(
# --> 467                         self._iter(fitted=fitted, replace_strings=True), 1))
#     468         except ValueError as e:
#     469             if "Expected 2D array, got 1D array instead" in str(e):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     408         """
#     409         self._validate_keywords()
# --> 410         return super().fit_transform(X, y)
#     411
#     412     def transform(self, X):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
# --> 693             return self.fit(X, y, **fit_params).transform(X)
#     694
#     695
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     383         """
#     384         self._validate_keywords()
# --> 385         self._fit(X, handle_unknown=self.handle_unknown)
#     386         self.drop_idx_ = self._compute_drop_idx()
#     387         return self
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown)
#      72
#      73     def _fit(self, X, handle_unknown='error'):
# ---> 74         X_list, n_samples, n_features = self._check_X(X)
#      75
#      76         if self.categories != 'auto':
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\preprocessing\_encoders.py in _check_X(self, X)
#      59             Xi = self._get_feature(X, feature_idx=i)
#      60             Xi = check_array(Xi, ensure_2d=False, dtype=None,
# ---> 61                              force_all_finite=needs_validation)
#      62             X_columns.append(Xi)
#      63
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     644         if force_all_finite:
#     645             _assert_all_finite(array,
# --> 646                                allow_nan=force_all_finite == 'allow-nan')
#     647
#     648     if ensure_min_samples > 0:
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     103     elif X.dtype == np.dtype('object') and not allow_nan:
#     104         if _object_dtype_isnan(X).any():
# --> 105             raise ValueError("Input contains NaN")
#     106
#     107
#
# ValueError: Input contains NaN

# %%
X_train
# Out:
#     IDENTIF RIVER  LOCATION   ERECTED   PURPOSE  LENGTH  LANES CLEAR-G  \
# 28      E28     M       3.0  EMERGING   HIGHWAY  MEDIUM    2.0       G
# 40      E41     M      11.0    MATURE   HIGHWAY     NaN    2.0       G
# 5        E7     A      27.0    CRAFTS   HIGHWAY   SHORT    2.0       N
# 53      E51     M       6.0    MATURE        RR  MEDIUM    2.0       G
# 107    E109     A      28.0    MODERN   HIGHWAY     NaN    NaN       G
# 39      E40     M      22.0    MATURE   HIGHWAY     NaN    2.0       G
# 35      E38     M      17.0    MATURE   HIGHWAY     NaN    2.0       G
# 16      E18     A      28.0    CRAFTS        RR  MEDIUM    2.0       N
# 78      E75     A      30.0    MATURE   HIGHWAY    LONG    4.0       G
# 34      E35     A      27.0    MATURE   HIGHWAY  MEDIUM    2.0       G
# 66      E60     A      24.0    MATURE   HIGHWAY  MEDIUM    4.0       G
# 7        E9     M       3.0    CRAFTS   HIGHWAY  MEDIUM    2.0       N
# 43      E43     M       7.0    MATURE   HIGHWAY  MEDIUM    2.0       G
# 65      E61     O      41.0    MATURE        RR    LONG    2.0       G
# 72      E70     A      27.0    MATURE   HIGHWAY   SHORT    4.0       G
# 27      E29     A      26.0  EMERGING   HIGHWAY  MEDIUM    2.0       G
# 19      E21     M      16.0  EMERGING        RR     NaN    2.0     NaN
# 90     E103     O      48.0    MODERN   HIGHWAY    LONG    2.0       G
# 105     E90     M       7.0    MODERN   HIGHWAY   SHORT    6.0       G
# 25      E26     M      12.0  EMERGING        RR  MEDIUM    2.0       G
# 68      E63     A      31.0    MATURE        RR    LONG    2.0       G
# 49      E94     M      13.0    MATURE        RR     NaN    2.0       G
# 13      E15     A      28.0    CRAFTS        RR     NaN    2.0       N
# 24      E27     A      39.0  EMERGING        RR     NaN    2.0       G
# 3        E5     A      29.0    CRAFTS   HIGHWAY  MEDIUM    2.0       N
# 17      E19     A      29.0    CRAFTS   HIGHWAY  MEDIUM    2.0       N
# 38       E4     A      27.0    MATURE  AQUEDUCT  MEDIUM    1.0       N
# 8       E10     A      39.0    CRAFTS  AQUEDUCT     NaN    1.0       N
# 84      E76     M       6.0    MATURE   HIGHWAY  MEDIUM    4.0       G
# 6        E8     A      28.0    CRAFTS  AQUEDUCT  MEDIUM    1.0       N
# 70      E64     A      29.0    MATURE   HIGHWAY   SHORT    4.0       G
# 94      E98     M      22.0    MODERN   HIGHWAY   SHORT    4.0       G
# 99     E102     O      47.0    MODERN   HIGHWAY  MEDIUM    2.0       G
# 54      E50     M      21.0    MATURE        RR  MEDIUM    NaN       G
# 50      E49     A      34.0    MATURE   HIGHWAY  MEDIUM    2.0       G
# 73      E69     A      26.0    MATURE   HIGHWAY   SHORT    4.0       G
# 46      E47     M      15.0    MATURE        RR    LONG    2.0       G
# 97      E88     A      37.0    MODERN   HIGHWAY    LONG    4.0       N
# 61      E57     O      49.0    MATURE        RR  MEDIUM    2.0       G
# 104     E91     O      44.0    MODERN   HIGHWAY    LONG    6.0       G
# 85      E93     M      11.0    MATURE   HIGHWAY  MEDIUM    4.0       N
# 41      E42     M       9.0    MATURE   HIGHWAY    LONG    2.0       G
# 58      E54     Y       NaN    MATURE   HIGHWAY  MEDIUM    NaN       G
# 48      E48     A      38.0    MATURE   HIGHWAY    LONG    2.0       G
# 93      E99     M      23.0    MODERN   HIGHWAY  MEDIUM    2.0       G
# 57      E52     M       2.0    MATURE        RR  MEDIUM    NaN       G
# 75      E73     A      38.0    MATURE   HIGHWAY  MEDIUM    NaN       G
# 32      E33     M      19.0  EMERGING   HIGHWAY  MEDIUM    NaN       G
# 101     E86     A      33.0    MODERN   HIGHWAY   SHORT    4.0       G
# 59      E56     M      23.0    MATURE   HIGHWAY     NaN    NaN       G
# 63     E107     A      39.0    MATURE        RR     NaN    NaN       G
# 91      E97     Y      52.0    MODERN   HIGHWAY     NaN    NaN       G
# 37      E39     A      25.0    MATURE   HIGHWAY     NaN    2.0       G
# 29      E32     A      30.0  EMERGING   HIGHWAY     NaN    2.0       G
# 96      E80     M      19.0    MODERN   HIGHWAY  MEDIUM    4.0       G
# 1        E2     A      25.0    CRAFTS   HIGHWAY  MEDIUM    2.0       N
# 52      E87     A      35.0    MATURE        RR    LONG    2.0       G
# 21      E22     A      24.0  EMERGING   HIGHWAY  MEDIUM    4.0       G
# 2        E3     A      39.0    CRAFTS  AQUEDUCT     NaN    1.0       N
# 23      E25     M      10.0  EMERGING        RR     NaN    2.0       G
# 87     E108     A      39.5    MODERN   HIGHWAY  MEDIUM    4.0       G
# 98      E82     O      42.0    MODERN   HIGHWAY   SHORT    NaN       G
# 74     E101     O      46.0    MATURE   HIGHWAY  MEDIUM    2.0       G
# 86      E79     A      34.0    MATURE   HIGHWAY  MEDIUM    4.0       G
# 82      E78     O      40.0    MATURE   HIGHWAY  MEDIUM    4.0       G
# 20      E23     M       1.0  EMERGING   HIGHWAY  MEDIUM    NaN     NaN
# 60      E55     A      36.0    MATURE   HIGHWAY  MEDIUM    2.0       G
# 71      E66     A      32.0    MATURE   HIGHWAY    LONG    4.0       G
# 14      E16     A      25.0    CRAFTS   HIGHWAY  MEDIUM    2.0       N
# 92      E96     Y      51.0    MODERN        RR     NaN    NaN       G
# 51      E95     M      16.0    MATURE        RR  MEDIUM    2.0       G
# 102     E85     M       9.0    MODERN   HIGHWAY    LONG    4.0       G
#
#       T-OR-D MATERIAL    SPAN REL-L
# 28   THROUGH    STEEL  MEDIUM     S
# 40   THROUGH     IRON  MEDIUM     F
# 5    THROUGH     WOOD  MEDIUM     S
# 53   THROUGH    STEEL  MEDIUM     F
# 107      NaN      NaN     NaN     F
# 39   THROUGH    STEEL  MEDIUM     F
# 35   THROUGH     IRON  MEDIUM     F
# 16   THROUGH     IRON   SHORT     S
# 78      DECK    STEEL  MEDIUM     F
# 34   THROUGH    STEEL  MEDIUM     F
# 66   THROUGH    STEEL    LONG     F
# 7    THROUGH     IRON   SHORT     S
# 43   THROUGH    STEEL    LONG     F
# 65   THROUGH    STEEL    LONG     F
# 72   THROUGH    STEEL  MEDIUM   S-F
# 27   THROUGH    STEEL  MEDIUM   NaN
# 19   THROUGH     IRON     NaN   NaN
# 90   THROUGH    STEEL    LONG     F
# 105  THROUGH    STEEL    LONG     F
# 25   THROUGH    STEEL  MEDIUM     S
# 68   THROUGH    STEEL  MEDIUM     F
# 49   THROUGH    STEEL    LONG     F
# 13   THROUGH     WOOD     NaN     S
# 24   THROUGH    STEEL     NaN     F
# 3    THROUGH     WOOD   SHORT     S
# 17   THROUGH     WOOD  MEDIUM     S
# 38   THROUGH     WOOD   SHORT     S
# 8       DECK     WOOD     NaN     S
# 84   THROUGH    STEEL    LONG     F
# 6    THROUGH     IRON   SHORT     S
# 70   THROUGH    STEEL  MEDIUM     F
# 94   THROUGH    STEEL  MEDIUM     F
# 99   THROUGH    STEEL    LONG     F
# 54   THROUGH    STEEL    LONG     F
# 50   THROUGH    STEEL  MEDIUM     F
# 73   THROUGH    STEEL  MEDIUM   S-F
# 46   THROUGH    STEEL  MEDIUM     S
# 97      DECK    STEEL    LONG     F
# 61   THROUGH    STEEL    LONG     F
# 104  THROUGH    STEEL    LONG     F
# 85      DECK    STEEL    LONG   S-F
# 41   THROUGH    STEEL    LONG     F
# 58       NaN    STEEL  MEDIUM     F
# 48   THROUGH    STEEL  MEDIUM     F
# 93   THROUGH    STEEL  MEDIUM   S-F
# 57   THROUGH    STEEL    LONG     F
# 75   THROUGH    STEEL  MEDIUM     S
# 32   THROUGH     IRON  MEDIUM     F
# 101     DECK    STEEL  MEDIUM   S-F
# 59   THROUGH    STEEL  MEDIUM     F
# 63       NaN    STEEL     NaN     F
# 91   THROUGH    STEEL  MEDIUM     S
# 37   THROUGH    STEEL  MEDIUM     F
# 29   THROUGH     IRON  MEDIUM     F
# 96   THROUGH    STEEL    LONG     F
# 1    THROUGH     WOOD   SHORT     S
# 52   THROUGH    STEEL  MEDIUM     S
# 21   THROUGH     WOOD   SHORT     S
# 2    THROUGH     WOOD     NaN     S
# 23       NaN    STEEL     NaN   NaN
# 87      DECK    STEEL  MEDIUM   S-F
# 98   THROUGH    STEEL     NaN     F
# 74   THROUGH    STEEL    LONG   S-F
# 86      DECK    STEEL  MEDIUM     F
# 82   THROUGH    STEEL    LONG     F
# 20   THROUGH    STEEL    LONG     F
# 60   THROUGH    STEEL    LONG     F
# 71   THROUGH    STEEL  MEDIUM     S
# 14   THROUGH     IRON  MEDIUM   S-F
# 92   THROUGH    STEEL  MEDIUM     F
# 51   THROUGH    STEEL  MEDIUM     S
# 102     DECK    STEEL    LONG     F

# %%
print ("score = %3.2f" %(grid.best_score_))
print (grid.best_params_)
# Out:
# score = 0.62
# {'randomforestclassifier__bootstrap': True, 'randomforestclassifier__max_depth': 15, 'randomforestclassifier__max_features': 'auto', 'randomforestclassifier__min_samples_leaf': 1, 'randomforestclassifier__min_samples_split': 3, 'randomforestclassifier__n_estimators': 50}

# %%
grid.predict(X_test)
# Out:
# array(['ARCH', 'WOOD', 'WOOD', 'SIMPLE-T', 'CONT-T', 'SIMPLE-T',
#        'SIMPLE-T', 'SIMPLE-T', 'CONT-T', 'WOOD', 'SIMPLE-T', 'SIMPLE-T',
#        'WOOD', 'SIMPLE-T', 'WOOD', 'SIMPLE-T', 'SIMPLE-T', 'SIMPLE-T',
#        'SIMPLE-T', 'SIMPLE-T', 'WOOD', 'SUSPEN', 'ARCH', 'SIMPLE-T',
#        'SIMPLE-T', 'SIMPLE-T', 'SIMPLE-T', 'SUSPEN', 'SIMPLE-T', 'SUSPEN',
#        'SIMPLE-T', 'SIMPLE-T', 'WOOD', 'SIMPLE-T', 'CONT-T'], dtype=object)

# %%
pipe_stack.predict(X_test)
# Out:
# array(['ARCH', 'WOOD', 'WOOD', 'SIMPLE-T', 'CONT-T', 'SIMPLE-T',
#        'SIMPLE-T', 'SIMPLE-T', 'SIMPLE-T', 'WOOD', 'SIMPLE-T', 'SIMPLE-T',
#        'WOOD', 'CANTILEV', 'WOOD', 'SIMPLE-T', 'SIMPLE-T', 'SIMPLE-T',
#        'SIMPLE-T', 'SIMPLE-T', 'WOOD', 'SUSPEN', 'ARCH', 'SIMPLE-T',
#        'SIMPLE-T', 'SIMPLE-T', 'SIMPLE-T', 'SUSPEN', 'SIMPLE-T', 'SUSPEN',
#        'SIMPLE-T', 'SIMPLE-T', 'WOOD', 'SIMPLE-T', 'CONT-T'], dtype=object)

# %%
print("model score: %.3f" % pipe_stack.score(X_test, y_test))
print(classification_report(y_test, predictions))
print(f1_score(y_true, y_pred))
fpr, tpr, thresholds = roc_curve(y_test, preds, pos_label=1)
auc = roc_auc_score(y_test, preds)
fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], color='navy', linestyle='--', label='random')
plt.title(f'AUC: {auc}')
ax.set_xlabel('False positive rate')
ax.set_ylabel('True positive rate')
# Out:
# model score: 0.829
